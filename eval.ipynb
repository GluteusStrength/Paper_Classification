# %%
# %cd ..
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")
import random
import os

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import gluonnlp as nlp
import numpy as np
from tqdm import tqdm, tqdm_notebook

device = torch.device("cuda:0") if torch.cuda.is_available() else "cpu"

# %%
# seed 고정
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True

seed_everything(0)

# %% [markdown]
# ### 평가 부분
# 1. 테스트를 진행하고자 하는 데이터셋을 불러온다.
# 2. 테스트를 진행하고자 하는 경우 논문 본문과 확인하고자 하는 하나의 타겟을 불러온다.
#     - 본 실험에서는 논문 연구분야 데이터셋 30000건 중 6000건에 대해서 테스트 데이터로 활용하였다.
#     - 해당 테스트 데이터는 RCMN_CD1은 nan값이 없고 그 외에는 NaN값이 존재하기에 스코어 계산에는 RCMN_CD1만 이용하였다.
#     - 테스트를 진행할 경우 타겟 열 하나를 직접 지정해준다.
#         - 바로 밑의 셀의 data.loc[:, ["PAPER_TEXT", 타겟 컬럼]]과 같은 방식으로 진행한다.
# 3. target.json에는 중분류 코드와 그에 해당하는 number가 들어가 있다. 이는 논문 연구분야 30000건에서 발췌하여 미리 저장해둔 json 파일이다.
# 4. 나머지 부분은 그대로 실행시키면 된다.

# %%
dataset = pd.read_csv("./test.csv", encoding = 'utf-8')
# 데이터셋은 논문 본문과 특정 컬럼만을 불러온다.
dataset = dataset.loc[:, ["PAPER_TEXT", "RCMN_CD1"]]
dataset.columns = ["PAPER_TEXT", "target"]
dataset
# Out:
#                                              PAPER_TEXT  target
# 0     서론 최근 사람의 감정을 인식하고 응용하는 분야가 많아지고 있다. 감정을 인식하고 ...  ED0701
# 1     서론 농어업 농어촌은 농산물 시장개방으로 인한 가격하락과 도농 간의 격차가 심화되어...  LB2006
# 2     INTRODUCTION The invisible inner damage of com...  EB0707
# 3     서론 전 세계적으로 국가 간 무역장벽이 없어지면서 글로벌 경쟁이 치열해 지고 있고 ...  SG0401
# 4     INTRODUCTION Developments in the ceramic mater...  EB0208
# ...                                                 ...     ...
# 5995  연구의 필요성 및 목적 인간의 모든 행위는 공간 속에서 이루어지므로 공간에 대한 정...  EI0101
# 5996  서론 최근 한국의 고등교육기관을 찾는 외국인 유학생 수가 급증하고 있다. 교육통계서...  HC0217
# 5997  서론 최근 해양레저산업선진국의 경우 해양레저 활동 범위의 확대에 따라 원거리 항해에...  EA1001
# 5998  서론 오늘날 대한민국의 대학도서관은 모기관인 대학의 조직 및 인력 축소로 인해 사서...  SI0405
# 5999  서론 인간의 뇌에서 일어나는 시각적 자극 대비 반응 과정에 대해 실험심리학에서는 자...  OB0103
#
# [6000 rows x 2 columns]

# %%
# target.json에는 중분류 코드와 중분류 정보가 담겨있다.
import json
with open("./target.json", "r") as f:
    d = json.load(f)

for i in range(len(dataset)):
    dataset.loc[i, "target"] = dataset.loc[i, "target"][:4]

# test 데이터프레임에 컬럼을 load한다.
t = []
for i in range(len(dataset)):
    t.append(d[dataset.loc[i, "target"]])
dataset["TARGET"] = t

# %%
def make_dataset(mode):
    data = dataset
    mk_data = []
    for sentence, label in tqdm(zip(data["PAPER_TEXT"], data["TARGET"])):
        # sentence_list = sentence.split(".")
        # sentences = []
        # for sentence in sentence_list:
        #     sentence = sentence.strip()
        #     if sentence != 'I' and sentence != 'II' and sentence != "" and sentence != " " and sentence != "표" and sentence != "그림":
        #         sentences.append(sentence)
        #         sentences.append(" [SEP] ")
        # sentences = sentences[:-1]
        # sentences.insert(0, "[CLS] ")
        data_ = [sentence, label]
        mk_data.append(data_)
    return mk_data

test_set = make_dataset("test")
# Out:
# 6000it [00:00, 1211293.03it/s]

# %%
from gluonnlp.vocab import Vocab
from kobert_tokenizer import KoBERTTokenizer
from transformers import BertTokenizer
from transformers import BertModel
import json
# 이를 불러오고자 한다면 return_dict는 무조건 false로 해야한다.
bertmodel = BertModel.from_pretrained("skt/kobert-base-v1", return_dict = False)
# tokenizer = KoBERTTokenizer.from_pretrained("skt/kobert-base-v1")
# 커스텀 trained vocab txt 파일을 가지고 BertTokenzier 생성
tokenizer = BertTokenizer.from_pretrained("./vocab.txt", do_basic_tokenize = False)
# vocab = nlp.vocab.BERTVocab.from_sentencepiece(tokenizer.vocab_file, padding_token = "[PAD]")
tok = tokenizer.tokenize
# customize vocab을 직접 불러온다.
with open("vocab.txt", "r") as f:
    vocab = f.readlines()
vocab = [voc.rstrip("\n") for voc in vocab]
dic = dict()
for i in range(len(vocab)):
    dic[vocab[i]] = i
# 최종적으로 vocab 형태를 만들어준다.
vocab = Vocab(dic)

# %%
bertmodel.resize_token_embeddings(len(vocab))
max_len = 128

# %%
# BERTDataset 형태로 변경하는 과정
class BERTDataset(Dataset):
    def __init__(self, dataset, sent_idx, label_idx, bert_tokenizer, vocab, max_len, pad, pair, mode = 'train'):
        transform = nlp.data.BERTSentenceTransform(bert_tokenizer, max_seq_length=max_len, pad=pad, pair=pair, vocab = vocab)
        self.mode = mode
        if self.mode == "train":
            self.sentences = [transform([i[sent_idx]]) for i in dataset]
            self.labels = [np.int32(i[label_idx]) for i in dataset]
        else:
            self.sentences = [transform(i) for i in dataset]

    def __getitem__(self, i):
        if self.mode == "train":
            return (self.sentences[i] + (self.labels[i], ))
        else:
            return self.sentences[i]

    def __len__(self):
        return (len(self.sentences))

data_test = BERTDataset(dataset = test_set, sent_idx = 0, label_idx = 1, bert_tokenizer = tok, vocab = vocab, max_len = max_len, pad = True, pair = False, mode = "test")
test_dataloader = DataLoader(data_test, batch_size = 1, num_workers = 4)

# %%
class BERTClassifier(nn.Module):
    def __init__(self, bert, hidden_size = 768, num_classes=365, dr_rate=None, params=None):
        super(BERTClassifier, self).__init__()
        self.bert = bert
        self.dr_rate = dr_rate
                 
        self.classifier = nn.Linear(hidden_size , num_classes)
        if dr_rate:
            self.dropout = nn.Dropout(p=dr_rate)
        torch.nn.init.kaiming_uniform(self.classifier.weight)
    
    def get_attention_mask(self, token_ids, valid_length):
        attention_mask = torch.zeros_like(token_ids)
        for i, v in enumerate(valid_length):
            attention_mask[i][:v] = 1
        return attention_mask.float()

    def forward(self, token_ids, valid_length, segment_ids):
        attention_mask = self.get_attention_mask(token_ids, valid_length)
        
        _, pooler = self.bert(input_ids = token_ids, token_type_ids = segment_ids.long(), attention_mask = attention_mask.float().to(token_ids.device))
        if self.dr_rate:
            out = self.dropout(pooler)
        return self.classifier(out)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = torch.load("./model.pt")
model.to(device)
# Out:
# BERTClassifier(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(8005, 768)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (classifier): Linear(in_features=768, out_features=365, bias=True)
#   (dropout): Dropout(p=0.1, inplace=False)
# )

# %%
# 해당 함수를 통해 test 결과를 반환.
def inference():  
    model.eval()
    outputs = []
    out_logits = []
    with torch.no_grad():
        for batch_id, (token_ids, valid_length, segment_ids) in tqdm(enumerate(test_dataloader)):
            token_ids = token_ids.long().to(device)
            segment_ids = segment_ids.long().to(device)
            
            valid_length= valid_length
    
            out = model(token_ids, valid_length, segment_ids)
    
            for i in out:
                logits = i
                logits = logits.detach().cpu().numpy()
                logits = np.argmax(logits)
            outputs.append(logits)
            out_logits.append(out)

        return outputs, out_logits

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score
# out 지정
out = inference()
# label 지정
labels = dataset["TARGET"]
# Out:
# 6000it [01:07, 88.76it/s]

# %%
output = out[0]
logits = out[1]
print("-------------------------------------------------")
print("accuracy score         |  {}".format(accuracy_score(output, labels)))
print("-------------------------------------------------")
print("precision macro score  |  {}".format(precision_score(output, labels, average = "macro")))
print("-------------------------------------------------")
print("precision micro score  |  {}".format(precision_score(output, labels, average = "micro")))
print("-------------------------------------------------")
print("recall macro score     |  {}".format(recall_score(output, labels, average = "macro")))
print("-------------------------------------------------")
print("recall micro score     |  {}".format(recall_score(output, labels, average = "micro")))
print("-------------------------------------------------")
# Out:
# -------------------------------------------------
# accuracy score         |  0.5988333333333333
# -------------------------------------------------
# precision macro score  |  0.5054755796695363
# -------------------------------------------------
# precision micro score  |  0.5988333333333333
# -------------------------------------------------
# recall macro score     |  0.5699121308731049
# -------------------------------------------------
# recall micro score     |  0.5988333333333333
# -------------------------------------------------

# %%
top_ = []
def mk_top3(tensor_data):
    t_data = tensor_data.cpu().numpy()
    top_indices = np.argsort(t_data)[-3:]
    top_values = t_data[top_indices]
    return top_indices
for outs in logits:
    top_.append(mk_top3(outs[0]))

# %%
# dataframe으로 보여준다.
key = list(d.keys())
top3_keys = pd.DataFrame(top_)
for i in range(len(top3_keys)):
    top3_keys.loc[i, 0] = key[top3_keys.loc[i, 0]]
    top3_keys.loc[i, 1] = key[top3_keys.loc[i, 1]]
    top3_keys.loc[i, 2] = key[top3_keys.loc[i, 2]]
top3_keys.columns = ["label1", "label2", "label3"]

# %%
top3_keys.to_csv("top3_keysout.csv", index = False)

# %%
top3_keys
# Out:
#      label1 label2 label3
# 0      EA05   NA06   ED07
# 1      SC04   SF02   SC06
# 2      EG02   EB01   EB07
# 3      SE05   SB12   SC07
# 4      EH07   EB05   EB02
# ...     ...    ...    ...
# 5995   SF03   SF02   EI01
# 5996   HC01   HC05   HC02
# 5997   EB01   EB06   EB07
# 5998   SI05   SI01   SI04
# 5999   LC05   SG02   OB01
#
# [6000 rows x 3 columns]

# %% [markdown]
# ### 유사 논문 추천 부분

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

def find_similar_documents(new_data, top_n=10):
    # final.csv 파일에서 데이터 불러오기
    final_dataset = pd.read_csv('final.csv', encoding='utf-8')
    final_dataset = final_dataset.head(100)
    final_dataset['PAPER_TEXT'].fillna('', inplace=True)
    
    results = []

    for i in range(len(new_data)):
        # 새로운 데이터를 가져옴
        new_document = new_data[i]

        # 전처리된 텍스트를 TF-IDF 벡터로 변환
        tfidf_vectorizer = TfidfVectorizer()
        tfidf_matrix = tfidf_vectorizer.fit_transform(final_dataset['PAPER_TEXT'] + [new_document])

        # 입력 문서와 다른 문서들 간의 Cosine Similarity 계산
        cosine_similarities = cosine_similarity(tfidf_matrix[-1], tfidf_matrix[:-1])

        # 가장 유사한 문서들의 인덱스 추출
        similar_documents_indices = cosine_similarities[0].argsort()[:-top_n-1:-1]

        # 결과를 리스트에 추가
        result = []
        for idx in similar_documents_indices:
            similarity_score = cosine_similarities[0][idx]
            item = {
                "인덱스": idx,
                "코사인 유사도": similarity_score,
                #"문서 이름": final_dataset['PAPER_NM_KO'].iloc[idx],
                "중분류 코드": final_dataset['target'].iloc[idx]
            }
            result.append(item)

        results.append(result)

    return results

# %%
find_similar_documents(dataset['PAPER_TEXT'], top_n=3)
# Out:
# [[{'인덱스': 70, '코사인 유사도': 0.577162794762542, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.5693437444023912, '중분류 코드': 'NC01'},
#   {'인덱스': 91, '코사인 유사도': 0.5689949453578996, '중분류 코드': 'NC01'}],
#  [{'인덱스': 56, '코사인 유사도': 0.6329701414982096, '중분류 코드': 'NB06'},
#   {'인덱스': 92, '코사인 유사도': 0.6315930138753715, '중분류 코드': 'NC01'},
#   {'인덱스': 70, '코사인 유사도': 0.6302168578777945, '중분류 코드': 'NB06'}],
#  [{'인덱스': 70, '코사인 유사도': 0.6934839766183589, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.6825775945458832, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.6794659276125377, '중분류 코드': 'NB06'}],
#  [{'인덱스': 94, '코사인 유사도': 0.4628313657696655, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.4593854470786078, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.4590057586478958, '중분류 코드': 'NB06'}],
#  [{'인덱스': 70, '코사인 유사도': 0.71935236832487, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.7114501489630135, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.7090245094516182, '중분류 코드': 'NC01'}],
#  [{'인덱스': 92, '코사인 유사도': 0.38695172776138004, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.3858036732577624, '중분류 코드': 'NC01'},
#   {'인덱스': 55, '코사인 유사도': 0.3773380136945851, '중분류 코드': 'NB06'}],
#  [{'인덱스': 97, '코사인 유사도': 0.28448631341214475, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.2666900900511555, '중분류 코드': 'NC01'},
#   {'인덱스': 61, '코사인 유사도': 0.2619053163770088, '중분류 코드': 'NB06'}],
#  [{'인덱스': 97, '코사인 유사도': 0.33472903029126233, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.3265124757882419, '중분류 코드': 'NC01'},
#   {'인덱스': 61, '코사인 유사도': 0.3230943138976396, '중분류 코드': 'NB06'}],
#  [{'인덱스': 70, '코사인 유사도': 0.4110274796111009, '중분류 코드': 'NB06'},
#   {'인덱스': 92, '코사인 유사도': 0.4093712324658403, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.40877514211282917, '중분류 코드': 'NC01'}],
#  [{'인덱스': 94, '코사인 유사도': 0.3641269327993938, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.3592277371335549, '중분류 코드': 'NC01'},
#   {'인덱스': 97, '코사인 유사도': 0.35772731399198326, '중분류 코드': 'NC01'}],
#  [{'인덱스': 94, '코사인 유사도': 0.3446683243492358, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.34392959948395624, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.33632202812006406, '중분류 코드': 'NB06'}],
#  [{'인덱스': 56, '코사인 유사도': 0.7637626796262571, '중분류 코드': 'NB06'},
#   {'인덱스': 70, '코사인 유사도': 0.7611508303354603, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.7604967372626391, '중분류 코드': 'NC01'}],
#  [{'인덱스': 92, '코사인 유사도': 0.4886949949873811, '중분류 코드': 'NC01'},
#   {'인덱스': 90, '코사인 유사도': 0.48117685241528035, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.48110834994510127, '중분류 코드': 'NB06'}],
#  [{'인덱스': 70, '코사인 유사도': 0.6338353635537302, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.6220342178220979, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.6198875702316705, '중분류 코드': 'NB06'}],
#  [{'인덱스': 61, '코사인 유사도': 0.3267021906826805, '중분류 코드': 'NB06'},
#   {'인덱스': 92, '코사인 유사도': 0.32557229861808185, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.3244813498032371, '중분류 코드': 'NC01'}],
#  [{'인덱스': 94, '코사인 유사도': 0.5096949250466805, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.5083756957329812, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.5067918307185839, '중분류 코드': 'NB06'}],
#  [{'인덱스': 94, '코사인 유사도': 0.44175577545406597, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.43874416520705906, '중분류 코드': 'NC01'},
#   {'인덱스': 61, '코사인 유사도': 0.4315302307674963, '중분류 코드': 'NB06'}],
#  [{'인덱스': 94, '코사인 유사도': 0.47538514018009553, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.47360716146613063, '중분류 코드': 'NB06'},
#   {'인덱스': 92, '코사인 유사도': 0.47224957718591437, '중분류 코드': 'NC01'}],
#  [{'인덱스': 94, '코사인 유사도': 0.35501733098531474, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.3500682537025044, '중분류 코드': 'NC01'},
#   {'인덱스': 55, '코사인 유사도': 0.3485194498774393, '중분류 코드': 'NB06'}],
#  [{'인덱스': 94, '코사인 유사도': 0.32064528688948607, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.3172409299515345, '중분류 코드': 'NC01'},
#   {'인덱스': 97, '코사인 유사도': 0.31582685063379895, '중분류 코드': 'NC01'}],
#  [{'인덱스': 70, '코사인 유사도': 0.790655449478003, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.7841967447739472, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.7814171547552323, '중분류 코드': 'NB06'}],
#  [{'인덱스': 92, '코사인 유사도': 0.46254082212294395, '중분류 코드': 'NC01'},
#   {'인덱스': 90, '코사인 유사도': 0.45478869918312625, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.45445289506255837, '중분류 코드': 'NC01'}],
#  [{'인덱스': 70, '코사인 유사도': 0.9281261425557369, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.9260932645119708, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.9252806782958366, '중분류 코드': 'NB06'}],
#  [{'인덱스': 70, '코사인 유사도': 0.8369884041643134, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.8317815565262597, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.8299282299617866, '중분류 코드': 'NB06'}],
#  [{'인덱스': 97, '코사인 유사도': 0.2969894927303459, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.296211516452277, '중분류 코드': 'NC01'},
#   {'인덱스': 61, '코사인 유사도': 0.2856754755782486, '중분류 코드': 'NB06'}],
#  [{'인덱스': 70, '코사인 유사도': 0.6054447053041997, '중분류 코드': 'NB06'},
#   {'인덱스': 56, '코사인 유사도': 0.6013020771808653, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.600967825703551, '중분류 코드': 'NC01'}],
#  [{'인덱스': 97, '코사인 유사도': 0.3553236907317985, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.34888695314181845, '중분류 코드': 'NC01'},
#   {'인덱스': 61, '코사인 유사도': 0.3432300380739923, '중분류 코드': 'NB06'}],
#  [{'인덱스': 94, '코사인 유사도': 0.35787906051772994, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.35358633358881614, '중분류 코드': 'NC01'},
#   {'인덱스': 97, '코사인 유사도': 0.35223310204052016, '중분류 코드': 'NC01'}],
#  [{'인덱스': 70, '코사인 유사도': 0.43223424262086285, '중분류 코드': 'NB06'},
#   {'인덱스': 92, '코사인 유사도': 0.4244542629607496, '중분류 코드': 'NC01'},
#   {'인덱스': 90, '코사인 유사도': 0.41933419095039226, '중분류 코드': 'NC01'}],
#  [{'인덱스': 94, '코사인 유사도': 0.32143538574172936, '중분류 코드': 'NC01'},
#   {'인덱스': 97, '코사인 유사도': 0.3202889075003193, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.3131898850725236, '중분류 코드': 'NC01'}],
#  [{'인덱스': 70, '코사인 유사도': 0.6863083231928437, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.6757078793314766, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.673330656538629, '중분류 코드': 'NB06'}],
#  [{'인덱스': 94, '코사인 유사도': 0.3850999119192697, '중분류 코드': 'NC01'},
#   {'인덱스': 97, '코사인 유사도': 0.38309871335281215, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.37983480181338186, '중분류 코드': 'NC01'}],
#  [{'인덱스': 94, '코사인 유사도': 0.4336128599089112, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.4282364047907946, '중분류 코드': 'NC01'},
#   {'인덱스': 61, '코사인 유사도': 0.4241651461514646, '중분류 코드': 'NB06'}],
#  [{'인덱스': 70, '코사인 유사도': 0.8652691629844003, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.8618352044623517, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.8587505779806783, '중분류 코드': 'NB06'}],
#  [{'인덱스': 56, '코사인 유사도': 0.6231542400342354, '중분류 코드': 'NB06'},
#   {'인덱스': 92, '코사인 유사도': 0.6200378957621453, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.6194281042338446, '중분류 코드': 'NC01'}],
#  [{'인덱스': 94, '코사인 유사도': 0.330787761312318, '중분류 코드': 'NC01'},
#   {'인덱스': 97, '코사인 유사도': 0.32166138521044085, '중분류 코드': 'NC01'},
#   {'인덱스': 55, '코사인 유사도': 0.3201668642572643, '중분류 코드': 'NB06'}],
#  [{'인덱스': 92, '코사인 유사도': 0.40567140237640775, '중분류 코드': 'NC01'},
#   {'인덱스': 70, '코사인 유사도': 0.40041132722408673, '중분류 코드': 'NB06'},
#   {'인덱스': 94, '코사인 유사도': 0.39994248592279097, '중분류 코드': 'NC01'}],
#  [{'인덱스': 70, '코사인 유사도': 0.788206873578459, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.780600185102206, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.7790544071464043, '중분류 코드': 'NB06'}],
#  [{'인덱스': 92, '코사인 유사도': 0.39747200269894895, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.3955859802473295, '중분류 코드': 'NC01'},
#   {'인덱스': 61, '코사인 유사도': 0.38984633473288094, '중분류 코드': 'NB06'}],
#  [{'인덱스': 70, '코사인 유사도': 0.8149103616916034, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.8099632276088949, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.8075943637783514, '중분류 코드': 'NB06'}],
#  [{'인덱스': 56, '코사인 유사도': 0.4995639756238486, '중분류 코드': 'NB06'},
#   {'인덱스': 94, '코사인 유사도': 0.49755246548391774, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.49568351190853704, '중분류 코드': 'NC01'}],
#  [{'인덱스': 97, '코사인 유사도': 0.31405027196523577, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.2991531121749983, '중분류 코드': 'NC01'},
#   {'인덱스': 61, '코사인 유사도': 0.2946060534787542, '중분류 코드': 'NB06'}],
#  [{'인덱스': 70, '코사인 유사도': 0.5417789675645295, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.5278437185471397, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.5233938703114562, '중분류 코드': 'NB06'}],
#  [{'인덱스': 70, '코사인 유사도': 0.5126454773116497, '중분류 코드': 'NB06'},
#   {'인덱스': 94, '코사인 유사도': 0.5086662098714725, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.5079993798264624, '중분류 코드': 'NC01'}],
#  [{'인덱스': 94, '코사인 유사도': 0.37430049877395055, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.3717901674167938, '중분류 코드': 'NC01'},
#   {'인덱스': 61, '코사인 유사도': 0.3658165948416683, '중분류 코드': 'NB06'}],
#  [{'인덱스': 94, '코사인 유사도': 0.4052661048540339, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.40104842110692185, '중분류 코드': 'NC01'},
#   {'인덱스': 70, '코사인 유사도': 0.3944561840272918, '중분류 코드': 'NB06'}],
#  [{'인덱스': 70, '코사인 유사도': 0.8195566495663938, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.8143604245330099, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.8136495042565293, '중분류 코드': 'NC01'}],
#  [{'인덱스': 70, '코사인 유사도': 0.8147335681534352, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.8098247201797694, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.8068262625398187, '중분류 코드': 'NC01'}],
#  [{'인덱스': 97, '코사인 유사도': 0.3029448892692589, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.30270372464987555, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.2933863142664881, '중분류 코드': 'NC01'}],
#  [{'인덱스': 70, '코사인 유사도': 0.830037012714543, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.8245896470281805, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.8223930697959105, '중분류 코드': 'NB06'}],
#  [{'인덱스': 92, '코사인 유사도': 0.4072373407761224, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.40324653440965064, '중분류 코드': 'NC01'},
#   {'인덱스': 55, '코사인 유사도': 0.4018441113177044, '중분류 코드': 'NB06'}],
#  [{'인덱스': 97, '코사인 유사도': 0.31986546723207626, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.31682643522530846, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.30919068504098274, '중분류 코드': 'NC01'}],
#  [{'인덱스': 56, '코사인 유사도': 0.5989491828276857, '중분류 코드': 'NB06'},
#   {'인덱스': 92, '코사인 유사도': 0.5941896451382199, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.5936737450615384, '중분류 코드': 'NC01'}],
#  [{'인덱스': 94, '코사인 유사도': 0.5158392968170434, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.5148679979652344, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.5134165465715358, '중분류 코드': 'NB06'}],
#  [{'인덱스': 97, '코사인 유사도': 0.2510608286695161, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.24568054904872702, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.24411383860909197, '중분류 코드': 'NC01'}],
#  [{'인덱스': 92, '코사인 유사도': 0.3756155858740076, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.36876009683415967, '중분류 코드': 'NC01'},
#   {'인덱스': 61, '코사인 유사도': 0.3685653802628543, '중분류 코드': 'NB06'}],
#  [{'인덱스': 70, '코사인 유사도': 0.46758101822639847, '중분류 코드': 'NB06'},
#   {'인덱스': 56, '코사인 유사도': 0.46650673243546187, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.46425188807602713, '중분류 코드': 'NC01'}],
#  [{'인덱스': 92, '코사인 유사도': 0.5135687653078216, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.5128142874194666, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.5120727710920773, '중분류 코드': 'NB06'}],
#  [{'인덱스': 61, '코사인 유사도': 0.29700923942698454, '중분류 코드': 'NB06'},
#   {'인덱스': 97, '코사인 유사도': 0.29632453340720755, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.29266583155813286, '중분류 코드': 'NC01'}],
#  [{'인덱스': 70, '코사인 유사도': 0.8046741740447734, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.7997934141274802, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.7961080185343686, '중분류 코드': 'NB06'}],
#  [{'인덱스': 97, '코사인 유사도': 0.3001216154000922, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.29530656958004264, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.2880673737862376, '중분류 코드': 'NC01'}],
#  [{'인덱스': 70, '코사인 유사도': 0.6422521224828497, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.6296344171351486, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.6235054743501276, '중분류 코드': 'NB06'}],
#  [{'인덱스': 56, '코사인 유사도': 0.762054124370328, '중분류 코드': 'NB06'},
#   {'인덱스': 70, '코사인 유사도': 0.7609438696113473, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.7604063727008149, '중분류 코드': 'NC01'}],
#  [{'인덱스': 94, '코사인 유사도': 0.341094652800306, '중분류 코드': 'NC01'},
#   {'인덱스': 97, '코사인 유사도': 0.3403627185089533, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.3287621388340217, '중분류 코드': 'NC01'}],
#  [{'인덱스': 92, '코사인 유사도': 0.48875882025405665, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.48671165929863425, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.48624006720312885, '중분류 코드': 'NB06'}],
#  [{'인덱스': 94, '코사인 유사도': 0.3225646479951392, '중분류 코드': 'NC01'},
#   {'인덱스': 97, '코사인 유사도': 0.3157919280742579, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.3136806345974858, '중분류 코드': 'NC01'}],
#  [{'인덱스': 70, '코사인 유사도': 0.861550992403017, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.8567741582931094, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.8529522919233123, '중분류 코드': 'NB06'}],
#  [{'인덱스': 92, '코사인 유사도': 0.39299736331577634, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.3894044325174521, '중분류 코드': 'NC01'},
#   {'인덱스': 61, '코사인 유사도': 0.38437912077697783, '중분류 코드': 'NB06'}],
#  [{'인덱스': 70, '코사인 유사도': 0.7221128130078256, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.7201601905591088, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.7193656357222366, '중분류 코드': 'NB06'}],
#  [{'인덱스': 94, '코사인 유사도': 0.40874075434330465, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.4062406895748073, '중분류 코드': 'NC01'},
#   {'인덱스': 55, '코사인 유사도': 0.40110353440578284, '중분류 코드': 'NB06'}],
#  [{'인덱스': 92, '코사인 유사도': 0.4007988650865546, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.3957444160279817, '중분류 코드': 'NC01'},
#   {'인덱스': 70, '코사인 유사도': 0.3922275822528839, '중분류 코드': 'NB06'}],
#  [{'인덱스': 70, '코사인 유사도': 0.5446650020285206, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.5439705779099067, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.5438324788839499, '중분류 코드': 'NC01'}],
#  [{'인덱스': 61, '코사인 유사도': 0.30466476153597044, '중분류 코드': 'NB06'},
#   {'인덱스': 94, '코사인 유사도': 0.2980409091998574, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.29768986555656807, '중분류 코드': 'NC01'}],
#  [{'인덱스': 94, '코사인 유사도': 0.3791493702803697, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.37528793791238735, '중분류 코드': 'NC01'},
#   {'인덱스': 55, '코사인 유사도': 0.3741014046969921, '중분류 코드': 'NB06'}],
#  [{'인덱스': 70, '코사인 유사도': 0.8800886288484283, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.8771079868568047, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.874238948321894, '중분류 코드': 'NB06'}],
#  [{'인덱스': 56, '코사인 유사도': 0.558084051273821, '중분류 코드': 'NB06'},
#   {'인덱스': 94, '코사인 유사도': 0.5572278372218332, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.5569946375992023, '중분류 코드': 'NC01'}],
#  [{'인덱스': 94, '코사인 유사도': 0.3882302035116341, '중분류 코드': 'NC01'},
#   {'인덱스': 97, '코사인 유사도': 0.3864618463075095, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.3835061603411955, '중분류 코드': 'NC01'}],
#  [{'인덱스': 70, '코사인 유사도': 0.7797940144557078, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.773109889704247, '중분류 코드': 'NC01'},
#   {'인덱스': 8, '코사인 유사도': 0.7687847099901911, '중분류 코드': 'ND10'}],
#  [{'인덱스': 94, '코사인 유사도': 0.41854894503860973, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.41593286250710415, '중분류 코드': 'NC01'},
#   {'인덱스': 97, '코사인 유사도': 0.40860572940106993, '중분류 코드': 'NC01'}],
#  [{'인덱스': 70, '코사인 유사도': 0.9434757904149804, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.9418244523484869, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.9408921576715967, '중분류 코드': 'NB06'}],
#  [{'인덱스': 92, '코사인 유사도': 0.4205834164707443, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.4198550972430009, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.4107802657371305, '중분류 코드': 'NB06'}],
#  [{'인덱스': 94, '코사인 유사도': 0.4786390293854108, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.4767650903660384, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.4724103946946991, '중분류 코드': 'NB06'}],
#  [{'인덱스': 97, '코사인 유사도': 0.35229416231825544, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.3509553223381591, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.34337440517523815, '중분류 코드': 'NC01'}],
#  [{'인덱스': 94, '코사인 유사도': 0.473552555929062, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.47152705650413285, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.4666679070459771, '중분류 코드': 'NB06'}],
#  [{'인덱스': 70, '코사인 유사도': 0.7626310770513769, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.7556824632408062, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.7544941140946413, '중분류 코드': 'NB06'}],
#  [{'인덱스': 94, '코사인 유사도': 0.5203932409258033, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.5201376687906638, '중분류 코드': 'NB06'},
#   {'인덱스': 92, '코사인 유사도': 0.5186696068324442, '중분류 코드': 'NC01'}],
#  [{'인덱스': 97, '코사인 유사도': 0.31281641602611066, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.30612373997135695, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.29936932638533403, '중분류 코드': 'NC01'}],
#  [{'인덱스': 70, '코사인 유사도': 0.6009156115371117, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.5905480486322439, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.5813723811270052, '중분류 코드': 'NB06'}],
#  [{'인덱스': 70, '코사인 유사도': 0.6566037693669968, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.647715178086039, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.6422894657072079, '중분류 코드': 'NB06'}],
#  [{'인덱스': 94, '코사인 유사도': 0.5359049364767638, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.535636160279322, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.5355894018494559, '중분류 코드': 'NB06'}],
#  [{'인덱스': 92, '코사인 유사도': 0.4845635183161234, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.4801508654011282, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.47984177947497725, '중분류 코드': 'NB06'}],
#  [{'인덱스': 70, '코사인 유사도': 0.4053442064898355, '중분류 코드': 'NB06'},
#   {'인덱스': 92, '코사인 유사도': 0.4012250143781414, '중분류 코드': 'NC01'},
#   {'인덱스': 91, '코사인 유사도': 0.3989002404513853, '중분류 코드': 'NC01'}],
#  [{'인덱스': 94, '코사인 유사도': 0.39608146504641123, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.3917845666815877, '중분류 코드': 'NC01'},
#   {'인덱스': 55, '코사인 유사도': 0.38741482774421804, '중분류 코드': 'NB06'}],
#  [{'인덱스': 97, '코사인 유사도': 0.27501794339796287, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.2661435229853351, '중분류 코드': 'NC01'},
#   {'인덱스': 61, '코사인 유사도': 0.2563690402384753, '중분류 코드': 'NB06'}],
#  [{'인덱스': 91, '코사인 유사도': 0.38375964944846597, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.3835876098506233, '중분류 코드': 'NC01'},
#   {'인덱스': 70, '코사인 유사도': 0.3821257803214006, '중분류 코드': 'NB06'}],
#  [{'인덱스': 97, '코사인 유사도': 0.37206146212989594, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.370642232959132, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.3646850715468363, '중분류 코드': 'NC01'}],
#  [{'인덱스': 70, '코사인 유사도': 0.6510107177429252, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.6412248421040319, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.6358607475711201, '중분류 코드': 'NB06'}],
#  [{'인덱스': 61, '코사인 유사도': 0.3294062614784623, '중분류 코드': 'NB06'},
#   {'인덱스': 94, '코사인 유사도': 0.32820698094356837, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.3274366345491394, '중분류 코드': 'NC01'}],
#  [{'인덱스': 94, '코사인 유사도': 0.3436000616509539, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.3432784376816132, '중분류 코드': 'NC01'},
#   {'인덱스': 70, '코사인 유사도': 0.34094009238379724, '중분류 코드': 'NB06'}],
#  [{'인덱스': 92, '코사인 유사도': 0.372752798570944, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.36868847112707237, '중분류 코드': 'NC01'},
#   {'인덱스': 61, '코사인 유사도': 0.36379264443152853, '중분류 코드': 'NB06'}],
#  [{'인덱스': 70, '코사인 유사도': 0.6030792325409651, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.5901428234733915, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.5879548292776557, '중분류 코드': 'NC01'}],
#  [{'인덱스': 70, '코사인 유사도': 0.8461893040746951, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.8414475710280948, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.8401265813928998, '중분류 코드': 'NB06'}],
#  [{'인덱스': 70, '코사인 유사도': 0.7140397427171068, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.7059641667465971, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.7012034232483311, '중분류 코드': 'NB06'}],
#  [{'인덱스': 94, '코사인 유사도': 0.47312593779527234, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.4714400762723833, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.4665088727012489, '중분류 코드': 'NB06'}],
#  [{'인덱스': 94, '코사인 유사도': 0.45944098727891025, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.4571456839999044, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.4509877978376538, '중분류 코드': 'NB06'}],
#  [{'인덱스': 92, '코사인 유사도': 0.3183749893472939, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.31513375528899135, '중분류 코드': 'NC01'},
#   {'인덱스': 61, '코사인 유사도': 0.3128929982553145, '중분류 코드': 'NB06'}],
#  [{'인덱스': 92, '코사인 유사도': 0.39192823842028174, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.38714110722537526, '중분류 코드': 'NC01'},
#   {'인덱스': 70, '코사인 유사도': 0.3848562130715356, '중분류 코드': 'NB06'}],
#  [{'인덱스': 94, '코사인 유사도': 0.33720279879462145, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.33438747086016957, '중분류 코드': 'NC01'},
#   {'인덱스': 97, '코사인 유사도': 0.33200007159132705, '중분류 코드': 'NC01'}],
#  [{'인덱스': 70, '코사인 유사도': 0.9038443140170782, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.9009714172126698, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.8998548092420409, '중분류 코드': 'NB06'}],
#  [{'인덱스': 92, '코사인 유사도': 0.4213197471358201, '중분류 코드': 'NC01'},
#   {'인덱스': 70, '코사인 유사도': 0.42049278074581614, '중분류 코드': 'NB06'},
#   {'인덱스': 94, '코사인 유사도': 0.41963382535549265, '중분류 코드': 'NC01'}],
#  [{'인덱스': 94, '코사인 유사도': 0.3491448367087205, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.3447005758291529, '중분류 코드': 'NC01'},
#   {'인덱스': 55, '코사인 유사도': 0.34242686697281804, '중분류 코드': 'NB06'}],
#  [{'인덱스': 94, '코사인 유사도': 0.3778042357220293, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.37061380486414147, '중분류 코드': 'NC01'},
#   {'인덱스': 55, '코사인 유사도': 0.3686389105524678, '중분류 코드': 'NB06'}],
#  [{'인덱스': 94, '코사인 유사도': 0.42688963542010355, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.422561688787529, '중분류 코드': 'NC01'},
#   {'인덱스': 55, '코사인 유사도': 0.4217345249122047, '중분류 코드': 'NB06'}],
#  [{'인덱스': 97, '코사인 유사도': 0.3581253659385981, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.356035695150904, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.35433393497380394, '중분류 코드': 'NC01'}],
#  [{'인덱스': 97, '코사인 유사도': 0.32920512065842356, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.32332114236988374, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.3218487598089923, '중분류 코드': 'NC01'}],
#  [{'인덱스': 70, '코사인 유사도': 0.8821723233347563, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.8788916116967529, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.8772837932084067, '중분류 코드': 'NB06'}],
#  [{'인덱스': 70, '코사인 유사도': 0.8768633061474059, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.8726931091149654, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.8717019767324901, '중분류 코드': 'NB06'}],
#  [{'인덱스': 97, '코사인 유사도': 0.3157262064494912, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.30076872143482536, '중분류 코드': 'NC01'},
#   {'인덱스': 61, '코사인 유사도': 0.2971997665867468, '중분류 코드': 'NB06'}],
#  [{'인덱스': 92, '코사인 유사도': 0.5138002915158377, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.5128269262122725, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.5113919361833291, '중분류 코드': 'NB06'}],
#  [{'인덱스': 97, '코사인 유사도': 0.3069437231724037, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.3021978549250376, '중분류 코드': 'NC01'},
#   {'인덱스': 61, '코사인 유사도': 0.2939549662852926, '중분류 코드': 'NB06'}],
#  [{'인덱스': 70, '코사인 유사도': 0.9266682430874709, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.9244854801154647, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.9235449344193115, '중분류 코드': 'NB06'}],
#  [{'인덱스': 70, '코사인 유사도': 0.7341744303232135, '중분류 코드': 'NB06'},
#   {'인덱스': 56, '코사인 유사도': 0.7336235662402181, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.7314589022088027, '중분류 코드': 'NC01'}],
#  [{'인덱스': 94, '코사인 유사도': 0.43555015862561686, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.4313952186872788, '중분류 코드': 'NC01'},
#   {'인덱스': 61, '코사인 유사도': 0.424787677391289, '중분류 코드': 'NB06'}],
#  [{'인덱스': 70, '코사인 유사도': 0.6444395539564338, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.6308657271286223, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.6257559457117237, '중분류 코드': 'NB06'}],
#  [{'인덱스': 97, '코사인 유사도': 0.3709404162276793, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.3694565778302617, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.3635624202439182, '중분류 코드': 'NC01'}],
#  [{'인덱스': 94, '코사인 유사도': 0.3941787171560367, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.39215986922449153, '중분류 코드': 'NC01'},
#   {'인덱스': 55, '코사인 유사도': 0.3875268960206427, '중분류 코드': 'NB06'}],
#  [{'인덱스': 94, '코사인 유사도': 0.4647228140715675, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.4627191582535512, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.4614113250413942, '중분류 코드': 'NB06'}],
#  [{'인덱스': 94, '코사인 유사도': 0.38229547282672405, '중분류 코드': 'NC01'},
#   {'인덱스': 97, '코사인 유사도': 0.37686748098131945, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.37660964369727123, '중분류 코드': 'NC01'}],
#  [{'인덱스': 70, '코사인 유사도': 0.9559934604758334, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.9547889830451487, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.9543823468309982, '중분류 코드': 'NB06'}],
#  [{'인덱스': 70, '코사인 유사도': 0.8813952816518812, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.8783090809366924, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.876541936278861, '중분류 코드': 'NB06'}],
#  [{'인덱스': 56, '코사인 유사도': 0.5562283757676186, '중분류 코드': 'NB06'},
#   {'인덱스': 94, '코사인 유사도': 0.5527638418784975, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.5527126196940079, '중분류 코드': 'NC01'}],
#  [{'인덱스': 94, '코사인 유사도': 0.35111128878580833, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.34469755259874507, '중분류 코드': 'NC01'},
#   {'인덱스': 97, '코사인 유사도': 0.34050612455407914, '중분류 코드': 'NC01'}],
#  [{'인덱스': 94, '코사인 유사도': 0.3365191195622955, '중분류 코드': 'NC01'},
#   {'인덱스': 97, '코사인 유사도': 0.3286818018031897, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.31472312172143097, '중분류 코드': 'NC01'}],
#  [{'인덱스': 94, '코사인 유사도': 0.47339009877623095, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.471604834775404, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.46648486372929315, '중분류 코드': 'NB06'}],
#  [{'인덱스': 92, '코사인 유사도': 0.37469490517671017, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.3725360163722008, '중분류 코드': 'NC01'},
#   {'인덱스': 61, '코사인 유사도': 0.3674734896862659, '중분류 코드': 'NB06'}],
#  [{'인덱스': 56, '코사인 유사도': 0.5828794468529026, '중분류 코드': 'NB06'},
#   {'인덱스': 94, '코사인 유사도': 0.5813596464055655, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.5810523474553585, '중분류 코드': 'NC01'}],
#  [{'인덱스': 70, '코사인 유사도': 0.943204387066375, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.9415332147380245, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.9404680738690092, '중분류 코드': 'NC01'}],
#  [{'인덱스': 70, '코사인 유사도': 0.5119846919137495, '중분류 코드': 'NB06'},
#   {'인덱스': 92, '코사인 유사도': 0.5090814139782084, '중분류 코드': 'NC01'},
#   {'인덱스': 90, '코사인 유사도': 0.5079410496525627, '중분류 코드': 'NC01'}],
#  [{'인덱스': 94, '코사인 유사도': 0.44069706796011027, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.43692263828768835, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.4358634281877547, '중분류 코드': 'NB06'}],
#  [{'인덱스': 97, '코사인 유사도': 0.35531018369639117, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.3485644906417638, '중분류 코드': 'NC01'},
#   {'인덱스': 61, '코사인 유사도': 0.34224721710246964, '중분류 코드': 'NB06'}],
#  [{'인덱스': 70, '코사인 유사도': 0.8702995282562056, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.8664985812686358, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.8655165469056573, '중분류 코드': 'NB06'}],
#  [{'인덱스': 70, '코사인 유사도': 0.8743634174718877, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.8713733214576385, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.8695447853261474, '중분류 코드': 'NB06'}],
#  [{'인덱스': 70, '코사인 유사도': 0.7708180036787182, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.7634776866261997, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.7615574816247905, '중분류 코드': 'NB06'}],
#  [{'인덱스': 92, '코사인 유사도': 0.4769910972699254, '중분류 코드': 'NC01'},
#   {'인덱스': 70, '코사인 유사도': 0.47502154409121516, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.4725737182303375, '중분류 코드': 'NC01'}],
#  [{'인덱스': 94, '코사인 유사도': 0.34120839938507325, '중분류 코드': 'NC01'},
#   {'인덱스': 97, '코사인 유사도': 0.3370419205682807, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.3357887398250304, '중분류 코드': 'NC01'}],
#  [{'인덱스': 94, '코사인 유사도': 0.5546916398446126, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.5539718709447725, '중분류 코드': 'NB06'},
#   {'인덱스': 92, '코사인 유사도': 0.5533838841887699, '중분류 코드': 'NC01'}],
#  [{'인덱스': 70, '코사인 유사도': 0.8762911433252157, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.872356672987576, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.8718437316225834, '중분류 코드': 'NB06'}],
#  [{'인덱스': 92, '코사인 유사도': 0.3916942921388012, '중분류 코드': 'NC01'},
#   {'인덱스': 61, '코사인 유사도': 0.3859470203351658, '중분류 코드': 'NB06'},
#   {'인덱스': 94, '코사인 유사도': 0.3835841150760967, '중분류 코드': 'NC01'}],
#  [{'인덱스': 56, '코사인 유사도': 0.7574115116529032, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.7534364010062793, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.7532363097914057, '중분류 코드': 'NC01'}],
#  [{'인덱스': 70, '코사인 유사도': 0.867071059823818, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.8633197680625522, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.8613009059413667, '중분류 코드': 'NB06'}],
#  [{'인덱스': 61, '코사인 유사도': 0.31877392142145045, '중분류 코드': 'NB06'},
#   {'인덱스': 92, '코사인 유사도': 0.3185557303222845, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.315810783523946, '중분류 코드': 'NC01'}],
#  [{'인덱스': 94, '코사인 유사도': 0.36936355151079014, '중분류 코드': 'NC01'},
#   {'인덱스': 97, '코사인 유사도': 0.3675763260958369, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.362648681468516, '중분류 코드': 'NC01'}],
#  [{'인덱스': 92, '코사인 유사도': 0.3819245564678544, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.3731877751052547, '중분류 코드': 'NC01'},
#   {'인덱스': 61, '코사인 유사도': 0.3719680719880404, '중분류 코드': 'NB06'}],
#  [{'인덱스': 94, '코사인 유사도': 0.5306656097993631, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.5302262437179653, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.5296180944936968, '중분류 코드': 'NB06'}],
#  [{'인덱스': 94, '코사인 유사도': 0.3917870884988048, '중분류 코드': 'NC01'},
#   {'인덱스': 97, '코사인 유사도': 0.3734675610950775, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.3722863986851049, '중분류 코드': 'NC01'}],
#  [{'인덱스': 97, '코사인 유사도': 0.342106074637772, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.3305583744072344, '중분류 코드': 'NC01'},
#   {'인덱스': 61, '코사인 유사도': 0.3260076656259486, '중분류 코드': 'NB06'}],
#  [{'인덱스': 70, '코사인 유사도': 0.7162214066239952, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.7065001552168786, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.7030433595607131, '중분류 코드': 'NB06'}],
#  [{'인덱스': 92, '코사인 유사도': 0.4531657202667606, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.4523363771159449, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.4442300664149166, '중분류 코드': 'NB06'}],
#  [{'인덱스': 94, '코사인 유사도': 0.3582693466054461, '중분류 코드': 'NC01'},
#   {'인덱스': 97, '코사인 유사도': 0.35636299574452407, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.35581842105622624, '중분류 코드': 'NC01'}],
#  [{'인덱스': 94, '코사인 유사도': 0.4380681178241124, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.436811512289743, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.4329398819995428, '중분류 코드': 'NB06'}],
#  [{'인덱스': 94, '코사인 유사도': 0.4020390428615478, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.4005355790451871, '중분류 코드': 'NC01'},
#   {'인덱스': 61, '코사인 유사도': 0.3935771991851045, '중분류 코드': 'NB06'}],
#  [{'인덱스': 70, '코사인 유사도': 0.7996559591692608, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.7938430433219914, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.791486946994968, '중분류 코드': 'NB06'}],
#  [{'인덱스': 70, '코사인 유사도': 0.7166823593927591, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.7075316097985376, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.7034090675281954, '중분류 코드': 'NB06'}],
#  [{'인덱스': 92, '코사인 유사도': 0.5299540426339202, '중분류 코드': 'NC01'},
#   {'인덱스': 70, '코사인 유사도': 0.5296861231014626, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.528883299167107, '중분류 코드': 'NC01'}],
#  [{'인덱스': 70, '코사인 유사도': 0.8335971975093319, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.8288205686529089, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.8277104855146884, '중분류 코드': 'NB06'}],
#  [{'인덱스': 70, '코사인 유사도': 0.4435789814506533, '중분류 코드': 'NB06'},
#   {'인덱스': 92, '코사인 유사도': 0.4240865176677443, '중분류 코드': 'NC01'},
#   {'인덱스': 90, '코사인 유사도': 0.4210769265781161, '중분류 코드': 'NC01'}],
#  [{'인덱스': 97, '코사인 유사도': 0.3113379944821832, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.30831343989293647, '중분류 코드': 'NC01'},
#   {'인덱스': 61, '코사인 유사도': 0.29687763930070066, '중분류 코드': 'NB06'}],
#  [{'인덱스': 94, '코사인 유사도': 0.47103091299401145, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.4692760602567832, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.4681185145916035, '중분류 코드': 'NB06'}],
#  [{'인덱스': 56, '코사인 유사도': 0.48354875700224054, '중분류 코드': 'NB06'},
#   {'인덱스': 92, '코사인 유사도': 0.48318517274513006, '중분류 코드': 'NC01'},
#   {'인덱스': 90, '코사인 유사도': 0.48085768267021056, '중분류 코드': 'NC01'}],
#  [{'인덱스': 56, '코사인 유사도': 0.6008966945854475, '중분류 코드': 'NB06'},
#   {'인덱스': 70, '코사인 유사도': 0.5997371407282024, '중분류 코드': 'NB06'},
#   {'인덱스': 92, '코사인 유사도': 0.5964530502812636, '중분류 코드': 'NC01'}],
#  [{'인덱스': 94, '코사인 유사도': 0.47616337009001525, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.4746379727585701, '중분류 코드': 'NC01'},
#   {'인덱스': 70, '코사인 유사도': 0.47161377163306045, '중분류 코드': 'NB06'}],
#  [{'인덱스': 70, '코사인 유사도': 0.9855776251749945, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.9851664192271611, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.9849365151646986, '중분류 코드': 'NB06'}],
#  [{'인덱스': 94, '코사인 유사도': 0.39922573175884507, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.3965091676383901, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.391460940184371, '중분류 코드': 'NB06'}],
#  [{'인덱스': 61, '코사인 유사도': 0.2788189709911118, '중분류 코드': 'NB06'},
#   {'인덱스': 92, '코사인 유사도': 0.27871223314140253, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.27802823747388106, '중분류 코드': 'NC01'}],
#  [{'인덱스': 70, '코사인 유사도': 0.7532701755425135, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.7447309052290279, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.7410093784276196, '중분류 코드': 'NC01'}],
#  [{'인덱스': 70, '코사인 유사도': 0.6122178800958341, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.5975906293543529, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.5939173288203015, '중분류 코드': 'NB06'}],
#  [{'인덱스': 92, '코사인 유사도': 0.3316168781852493, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.32995743891707097, '중분류 코드': 'NC01'},
#   {'인덱스': 61, '코사인 유사도': 0.3287431073965687, '중분류 코드': 'NB06'}],
#  [{'인덱스': 92, '코사인 유사도': 0.3814987666626872, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.37923730355216617, '중분류 코드': 'NC01'},
#   {'인덱스': 61, '코사인 유사도': 0.374660224118803, '중분류 코드': 'NB06'}],
#  [{'인덱스': 94, '코사인 유사도': 0.5311957800588885, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.5305387074285731, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.530156042018028, '중분류 코드': 'NB06'}],
#  [{'인덱스': 97, '코사인 유사도': 0.3423703995508284, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.33376031918174803, '중분류 코드': 'NC01'},
#   {'인덱스': 61, '코사인 유사도': 0.3313254188331275, '중분류 코드': 'NB06'}],
#  [{'인덱스': 92, '코사인 유사도': 0.5550405947012899, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.5545034946420426, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.552096927798778, '중분류 코드': 'NC01'}],
#  [{'인덱스': 94, '코사인 유사도': 0.32107882554545664, '중분류 코드': 'NC01'},
#   {'인덱스': 97, '코사인 유사도': 0.3191057232039953, '중분류 코드': 'NC01'},
#   {'인덱스': 55, '코사인 유사도': 0.31637892047552896, '중분류 코드': 'NB06'}],
#  [{'인덱스': 94, '코사인 유사도': 0.4202616643995953, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.41836443686623964, '중분류 코드': 'NC01'},
#   {'인덱스': 55, '코사인 유사도': 0.4101244221751502, '중분류 코드': 'NB06'}],
#  [{'인덱스': 94, '코사인 유사도': 0.3982200044195789, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.3955201336678099, '중분류 코드': 'NC01'},
#   {'인덱스': 55, '코사인 유사도': 0.38880155780553366, '중분류 코드': 'NB06'}],
#  [{'인덱스': 94, '코사인 유사도': 0.3199868303863838, '중분류 코드': 'NC01'},
#   {'인덱스': 97, '코사인 유사도': 0.31443717127456106, '중분류 코드': 'NC01'},
#   {'인덱스': 55, '코사인 유사도': 0.3100283728519014, '중분류 코드': 'NB06'}],
#  [{'인덱스': 70, '코사인 유사도': 0.7805386117710115, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.7767210538434212, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.7718538908909043, '중분류 코드': 'NB06'}],
#  [{'인덱스': 56, '코사인 유사도': 0.6270295760291608, '중분류 코드': 'NB06'},
#   {'인덱스': 92, '코사인 유사도': 0.6249176229386367, '중분류 코드': 'NC01'},
#   {'인덱스': 90, '코사인 유사도': 0.6236827835240201, '중분류 코드': 'NC01'}],
#  [{'인덱스': 70, '코사인 유사도': 0.5286008114022528, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.5240215406832317, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.523785270785279, '중분류 코드': 'NB06'}],
#  [{'인덱스': 94, '코사인 유사도': 0.31432611512211905, '중분류 코드': 'NC01'},
#   {'인덱스': 97, '코사인 유사도': 0.3100900960674457, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.30441672838377476, '중분류 코드': 'NC01'}],
#  [{'인덱스': 94, '코사인 유사도': 0.31104572413782494, '중분류 코드': 'NC01'},
#   {'인덱스': 97, '코사인 유사도': 0.3047660170597553, '중분류 코드': 'NC01'},
#   {'인덱스': 55, '코사인 유사도': 0.3004091163309055, '중분류 코드': 'NB06'}],
#  [{'인덱스': 92, '코사인 유사도': 0.3536907887494357, '중분류 코드': 'NC01'},
#   {'인덱스': 61, '코사인 유사도': 0.3492204956727605, '중분류 코드': 'NB06'},
#   {'인덱스': 94, '코사인 유사도': 0.34553412699081104, '중분류 코드': 'NC01'}],
#  [{'인덱스': 94, '코사인 유사도': 0.390985968728941, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.38812777513078306, '중분류 코드': 'NC01'},
#   {'인덱스': 61, '코사인 유사도': 0.3801307371000499, '중분류 코드': 'NB06'}],
#  [{'인덱스': 97, '코사인 유사도': 0.3620567065936415, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.3548421337880111, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.35455450090315316, '중분류 코드': 'NC01'}],
#  [{'인덱스': 97, '코사인 유사도': 0.3020561604934518, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.291202129304524, '중분류 코드': 'NC01'},
#   {'인덱스': 61, '코사인 유사도': 0.2850801256178732, '중분류 코드': 'NB06'}],
#  [{'인덱스': 70, '코사인 유사도': 0.910943698079842, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.9084951672794637, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.9070110139373091, '중분류 코드': 'NB06'}],
#  [{'인덱스': 70, '코사인 유사도': 0.5366589218387453, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.5188911695267926, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.5163071811876537, '중분류 코드': 'NC01'}],
#  [{'인덱스': 94, '코사인 유사도': 0.49878147837114895, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.4983661976444878, '중분류 코드': 'NB06'},
#   {'인덱스': 92, '코사인 유사도': 0.49766372583443685, '중분류 코드': 'NC01'}],
#  [{'인덱스': 70, '코사인 유사도': 0.47961202214733434, '중분류 코드': 'NB06'},
#   {'인덱스': 56, '코사인 유사도': 0.4775093448798387, '중분류 코드': 'NB06'},
#   {'인덱스': 92, '코사인 유사도': 0.47734587745679935, '중분류 코드': 'NC01'}],
#  [{'인덱스': 92, '코사인 유사도': 0.3884694172149425, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.38084716089995985, '중분류 코드': 'NC01'},
#   {'인덱스': 61, '코사인 유사도': 0.38024758227380445, '중분류 코드': 'NB06'}],
#  [{'인덱스': 92, '코사인 유사도': 0.2923380207797272, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.2894847902018932, '중분류 코드': 'NC01'},
#   {'인덱스': 61, '코사인 유사도': 0.2888014049661688, '중분류 코드': 'NB06'}],
#  [{'인덱스': 70, '코사인 유사도': 0.8930099191529767, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.8900171675734004, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.8887987945372648, '중분류 코드': 'NB06'}],
#  [{'인덱스': 56, '코사인 유사도': 0.5472754370370627, '중분류 코드': 'NB06'},
#   {'인덱스': 70, '코사인 유사도': 0.5468959146539977, '중분류 코드': 'NB06'},
#   {'인덱스': 92, '코사인 유사도': 0.5453381349313722, '중분류 코드': 'NC01'}],
#  [{'인덱스': 92, '코사인 유사도': 0.3637631419810476, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.3616433035849427, '중분류 코드': 'NC01'},
#   {'인덱스': 61, '코사인 유사도': 0.36151337987696147, '중분류 코드': 'NB06'}],
#  [{'인덱스': 56, '코사인 유사도': 0.5671986504461551, '중분류 코드': 'NB06'},
#   {'인덱스': 94, '코사인 유사도': 0.5671563903861797, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.5656956229670632, '중분류 코드': 'NC01'}],
#  [{'인덱스': 92, '코사인 유사도': 0.325866858106505, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.3225068662412476, '중분류 코드': 'NC01'},
#   {'인덱스': 61, '코사인 유사도': 0.3210350595673664, '중분류 코드': 'NB06'}],
#  [{'인덱스': 70, '코사인 유사도': 0.6141742836580366, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.6019119252375883, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.6011573415248794, '중분류 코드': 'NB06'}],
#  [{'인덱스': 70, '코사인 유사도': 0.7829726721002351, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.7755701300082699, '중분류 코드': 'NC01'},
#   {'인덱스': 8, '코사인 유사도': 0.7754052681501608, '중분류 코드': 'ND10'}],
#  [{'인덱스': 92, '코사인 유사도': 0.47077042710362677, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.46948390942790763, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.46832449958598704, '중분류 코드': 'NB06'}],
#  [{'인덱스': 97, '코사인 유사도': 0.33907710382992506, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.3264883693184978, '중분류 코드': 'NC01'},
#   {'인덱스': 61, '코사인 유사도': 0.321679528263176, '중분류 코드': 'NB06'}],
#  [{'인덱스': 70, '코사인 유사도': 0.7735566453948215, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.7661126547459356, '중분류 코드': 'NC01'},
#   {'인덱스': 8, '코사인 유사도': 0.763751958464416, '중분류 코드': 'ND10'}],
#  [{'인덱스': 70, '코사인 유사도': 0.3938617298526759, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.3761491691556455, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.3753640269278237, '중분류 코드': 'NC01'}],
#  [{'인덱스': 70, '코사인 유사도': 0.629228506654756, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.6186097864742438, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.6137100501509993, '중분류 코드': 'NB06'}],
#  [{'인덱스': 70, '코사인 유사도': 0.6164616278952832, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.6157615172277257, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.6148696358244615, '중분류 코드': 'NB06'}],
#  [{'인덱스': 94, '코사인 유사도': 0.44454932318038515, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.4424487951451971, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.4411991083779982, '중분류 코드': 'NB06'}],
#  [{'인덱스': 92, '코사인 유사도': 0.3800268377449003, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.3750816584811273, '중분류 코드': 'NC01'},
#   {'인덱스': 61, '코사인 유사도': 0.372179855082283, '중분류 코드': 'NB06'}],
#  [{'인덱스': 94, '코사인 유사도': 0.39939006574795016, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.39475955484783004, '중분류 코드': 'NC01'},
#   {'인덱스': 97, '코사인 유사도': 0.3941847812284028, '중분류 코드': 'NC01'}],
#  [{'인덱스': 70, '코사인 유사도': 0.826684098067501, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.8217165377416514, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.8195970197134849, '중분류 코드': 'NB06'}],
#  [{'인덱스': 94, '코사인 유사도': 0.44797588114775666, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.44694824197806843, '중분류 코드': 'NC01'},
#   {'인덱스': 55, '코사인 유사도': 0.4432319039948825, '중분류 코드': 'NB06'}],
#  [{'인덱스': 97, '코사인 유사도': 0.3261386711682888, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.32581571387005637, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.32540454886254205, '중분류 코드': 'NC01'}],
#  [{'인덱스': 70, '코사인 유사도': 0.7206071998041002, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.7129537404508877, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.7083372990502522, '중분류 코드': 'NB06'}],
#  [{'인덱스': 94, '코사인 유사도': 0.42749644773099965, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.42725427507069863, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.41958733040807733, '중분류 코드': 'NB06'}],
#  [{'인덱스': 92, '코사인 유사도': 0.3978355546244911, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.39198264576201514, '중분류 코드': 'NC01'},
#   {'인덱스': 61, '코사인 유사도': 0.3913133867307005, '중분류 코드': 'NB06'}],
#  [{'인덱스': 94, '코사인 유사도': 0.4527816330009236, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.45008096375633677, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.4429822284357804, '중분류 코드': 'NB06'}],
#  [{'인덱스': 56, '코사인 유사도': 0.6656744646090026, '중분류 코드': 'NB06'},
#   {'인덱스': 92, '코사인 유사도': 0.6616063881713508, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.6605345629244204, '중분류 코드': 'NC01'}],
#  [{'인덱스': 92, '코사인 유사도': 0.32314169808239207, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.32197129832704624, '중분류 코드': 'NC01'},
#   {'인덱스': 61, '코사인 유사도': 0.32043170263750204, '중분류 코드': 'NB06'}],
#  [{'인덱스': 70, '코사인 유사도': 0.47961894496378127, '중분류 코드': 'NB06'},
#   {'인덱스': 92, '코사인 유사도': 0.47616421357766475, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.4757898487912503, '중분류 코드': 'NC01'}],
#  [{'인덱스': 92, '코사인 유사도': 0.5020804126549776, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.49899871628422177, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.4986534555885686, '중분류 코드': 'NC01'}],
#  [{'인덱스': 70, '코사인 유사도': 0.5501143068309917, '중분류 코드': 'NB06'},
#   {'인덱스': 56, '코사인 유사도': 0.5493757897737144, '중분류 코드': 'NB06'},
#   {'인덱스': 94, '코사인 유사도': 0.5475296131271542, '중분류 코드': 'NC01'}],
#  [{'인덱스': 97, '코사인 유사도': 0.32666241230345916, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.3231261371205584, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.32014027937258827, '중분류 코드': 'NC01'}],
#  [{'인덱스': 94, '코사인 유사도': 0.34443112804169823, '중분류 코드': 'NC01'},
#   {'인덱스': 97, '코사인 유사도': 0.34236568332071876, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.33919212811672605, '중분류 코드': 'NC01'}],
#  [{'인덱스': 70, '코사인 유사도': 0.5079803516650165, '중분류 코드': 'NB06'},
#   {'인덱스': 56, '코사인 유사도': 0.5078386130412501, '중분류 코드': 'NB06'},
#   {'인덱스': 92, '코사인 유사도': 0.507788203668539, '중분류 코드': 'NC01'}],
#  [{'인덱스': 94, '코사인 유사도': 0.40412908086872495, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.3974481781780464, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.3934702536053152, '중분류 코드': 'NB06'}],
#  [{'인덱스': 70, '코사인 유사도': 0.7598615024105582, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.7537144091528072, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.7506553379198477, '중분류 코드': 'NB06'}],
#  [{'인덱스': 94, '코사인 유사도': 0.41214070379455225, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.409374220414539, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.4060137750862363, '중분류 코드': 'NB06'}],
#  [{'인덱스': 94, '코사인 유사도': 0.4064844879778339, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.40215048618813165, '중분류 코드': 'NC01'},
#   {'인덱스': 97, '코사인 유사도': 0.39975758745260437, '중분류 코드': 'NC01'}],
#  [{'인덱스': 97, '코사인 유사도': 0.28865549998420026, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.2879318230619279, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.2771684334468247, '중분류 코드': 'NC01'}],
#  [{'인덱스': 70, '코사인 유사도': 0.7511317052149891, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.7442503940257489, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.7394183063027991, '중분류 코드': 'NB06'}],
#  [{'인덱스': 70, '코사인 유사도': 0.8564287229693647, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.8525260441718139, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.8506627995825566, '중분류 코드': 'NB06'}],
#  [{'인덱스': 94, '코사인 유사도': 0.4224757771717222, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.42197746863000724, '중분류 코드': 'NC01'},
#   {'인덱스': 55, '코사인 유사도': 0.4126515497422209, '중분류 코드': 'NB06'}],
#  [{'인덱스': 70, '코사인 유사도': 0.9294579080723113, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.9272736929629267, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.9267373813279753, '중분류 코드': 'NB06'}],
#  [{'인덱스': 94, '코사인 유사도': 0.39527193719381626, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.3897945545240813, '중분류 코드': 'NC01'},
#   {'인덱스': 55, '코사인 유사도': 0.3881410666049413, '중분류 코드': 'NB06'}],
#  [{'인덱스': 70, '코사인 유사도': 0.8137690391098171, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.8084491144009252, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.8051408810762097, '중분류 코드': 'NB06'}],
#  [{'인덱스': 94, '코사인 유사도': 0.4215152182659605, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.41927643502123063, '중분류 코드': 'NC01'},
#   {'인덱스': 55, '코사인 유사도': 0.4163048472045059, '중분류 코드': 'NB06'}],
#  [{'인덱스': 94, '코사인 유사도': 0.38469311943824125, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.3804002420669297, '중분류 코드': 'NC01'},
#   {'인덱스': 97, '코사인 유사도': 0.3803848160200105, '중분류 코드': 'NC01'}],
#  [{'인덱스': 70, '코사인 유사도': 0.8644539607510284, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.8610154929925135, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.8589052549375228, '중분류 코드': 'NB06'}],
#  [{'인덱스': 70, '코사인 유사도': 0.5539548169678928, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.5504046083292334, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.5483270790988344, '중분류 코드': 'NC01'}],
#  [{'인덱스': 97, '코사인 유사도': 0.34040908952951426, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.3330180687904799, '중분류 코드': 'NC01'},
#   {'인덱스': 61, '코사인 유사도': 0.325898435832784, '중분류 코드': 'NB06'}],
#  [{'인덱스': 70, '코사인 유사도': 0.8904605358553827, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.8865035392121333, '중분류 코드': 'NC01'},
# ...
#   {'인덱스': 97, '코사인 유사도': 0.3635634038930919, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.3595354255450238, '중분류 코드': 'NC01'}],
#  [{'인덱스': 92, '코사인 유사도': 0.33979536387410736, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.3381548904965864, '중분류 코드': 'NC01'},
#   {'인덱스': 55, '코사인 유사도': 0.33210710749100303, '중분류 코드': 'NB06'}],
#  [{'인덱스': 92, '코사인 유사도': 0.449886096936135, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.4492087592145204, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.44490780190471696, '중분류 코드': 'NB06'}],
#  [{'인덱스': 94, '코사인 유사도': 0.3596689169690173, '중분류 코드': 'NC01'},
#   {'인덱스': 97, '코사인 유사도': 0.35632408295383355, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.3556912852657708, '중분류 코드': 'NC01'}],
#  [{'인덱스': 56, '코사인 유사도': 0.647220969018649, '중분류 코드': 'NB06'},
#   {'인덱스': 92, '코사인 유사도': 0.646317374056136, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.6446070137639174, '중분류 코드': 'NC01'}],
#  [{'인덱스': 70, '코사인 유사도': 0.8304000953015868, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.825004088851322, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.8234417010211309, '중분류 코드': 'NB06'}],
#  [{'인덱스': 92, '코사인 유사도': 0.4527919256626054, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.45056908765583525, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.4477551319679856, '중분류 코드': 'NB06'}],
#  [{'인덱스': 94, '코사인 유사도': 0.41830122955565285, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.41547019080452957, '중분류 코드': 'NC01'},
#   {'인덱스': 55, '코사인 유사도': 0.4116009571809723, '중분류 코드': 'NB06'}],
#  [{'인덱스': 97, '코사인 유사도': 0.2651040366126074, '중분류 코드': 'NC01'},
#   {'인덱스': 61, '코사인 유사도': 0.26381354330993084, '중분류 코드': 'NB06'},
#   {'인덱스': 92, '코사인 유사도': 0.2599366066689608, '중분류 코드': 'NC01'}],
#  [{'인덱스': 97, '코사인 유사도': 0.32751006732529486, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.318705534273434, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.30826151354074616, '중분류 코드': 'NC01'}],
#  [{'인덱스': 70, '코사인 유사도': 0.6776297695307212, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.668694988267103, '중분류 코드': 'NC01'},
#   {'인덱스': 8, '코사인 유사도': 0.6627297310317634, '중분류 코드': 'ND10'}],
#  [{'인덱스': 70, '코사인 유사도': 0.5954339388180978, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.5803279178345332, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.5745747884845366, '중분류 코드': 'NB06'}],
#  [{'인덱스': 92, '코사인 유사도': 0.33898134145155506, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.3389259759799418, '중분류 코드': 'NC01'},
#   {'인덱스': 61, '코사인 유사도': 0.3351430339079888, '중분류 코드': 'NB06'}],
#  [{'인덱스': 70, '코사인 유사도': 0.9086409191326984, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.9061815663211491, '중분류 코드': 'NC01'},
#   {'인덱스': 28, '코사인 유사도': 0.9048525781807153, '중분류 코드': 'ND10'}],
#  [{'인덱스': 97, '코사인 유사도': 0.33918943499300197, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.3261532460044592, '중분류 코드': 'NC01'},
#   {'인덱스': 61, '코사인 유사도': 0.3220152711491369, '중분류 코드': 'NB06'}],
#  [{'인덱스': 70, '코사인 유사도': 0.8247468633741939, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.818644174241876, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.8174685340046323, '중분류 코드': 'NB06'}],
#  [{'인덱스': 70, '코사인 유사도': 0.6636286382332388, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.6529607198423947, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.6455521028929734, '중분류 코드': 'NB06'}],
#  [{'인덱스': 94, '코사인 유사도': 0.32383725755070863, '중분류 코드': 'NC01'},
#   {'인덱스': 55, '코사인 유사도': 0.31665610580507525, '중분류 코드': 'NB06'},
#   {'인덱스': 97, '코사인 유사도': 0.3161130665248003, '중분류 코드': 'NC01'}],
#  [{'인덱스': 94, '코사인 유사도': 0.5041075995254602, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.5028692436938412, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.5006593025333597, '중분류 코드': 'NB06'}],
#  [{'인덱스': 94, '코사인 유사도': 0.5464752199090716, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.5464510917055804, '중분류 코드': 'NB06'},
#   {'인덱스': 92, '코사인 유사도': 0.5459910519515672, '중분류 코드': 'NC01'}],
#  [{'인덱스': 97, '코사인 유사도': 0.29511986167150667, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.2942311153778946, '중분류 코드': 'NC01'},
#   {'인덱스': 61, '코사인 유사도': 0.2840847307674642, '중분류 코드': 'NB06'}],
#  [{'인덱스': 92, '코사인 유사도': 0.4067757577496828, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.4005904208732257, '중분류 코드': 'NC01'},
#   {'인덱스': 61, '코사인 유사도': 0.39440004429216713, '중분류 코드': 'NB06'}],
#  [{'인덱스': 61, '코사인 유사도': 0.2678886714059869, '중분류 코드': 'NB06'},
#   {'인덱스': 97, '코사인 유사도': 0.2678103508814368, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.265959058581567, '중분류 코드': 'NC01'}],
#  [{'인덱스': 94, '코사인 유사도': 0.4252858346499762, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.4216894183399064, '중분류 코드': 'NC01'},
#   {'인덱스': 61, '코사인 유사도': 0.4156619739689468, '중분류 코드': 'NB06'}],
#  [{'인덱스': 92, '코사인 유사도': 0.3482632892646572, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.34646029063187495, '중분류 코드': 'NC01'},
#   {'인덱스': 97, '코사인 유사도': 0.3416371130009119, '중분류 코드': 'NC01'}],
#  [{'인덱스': 94, '코사인 유사도': 0.5204825448792947, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.5196074608435358, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.5185548748803867, '중분류 코드': 'NB06'}],
#  [{'인덱스': 70, '코사인 유사도': 0.7963134264906666, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.7897894586246641, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.787210166236379, '중분류 코드': 'NC01'}],
#  [{'인덱스': 70, '코사인 유사도': 0.6327545217915084, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.622699392271742, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.6179352056987725, '중분류 코드': 'NC01'}],
#  [{'인덱스': 94, '코사인 유사도': 0.4106815426178774, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.40917707953729465, '중분류 코드': 'NC01'},
#   {'인덱스': 61, '코사인 유사도': 0.401354084251711, '중분류 코드': 'NB06'}],
#  [{'인덱스': 56, '코사인 유사도': 0.7218425330253831, '중분류 코드': 'NB06'},
#   {'인덱스': 92, '코사인 유사도': 0.7176628728106178, '중분류 코드': 'NC01'},
#   {'인덱스': 90, '코사인 유사도': 0.7169560531243852, '중분류 코드': 'NC01'}],
#  [{'인덱스': 56, '코사인 유사도': 0.6209437947469819, '중분류 코드': 'NB06'},
#   {'인덱스': 70, '코사인 유사도': 0.6196903584285285, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.6187703378790266, '중분류 코드': 'NC01'}],
#  [{'인덱스': 70, '코사인 유사도': 0.8852573184252713, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.882662909508108, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.8802609916217333, '중분류 코드': 'NB06'}],
#  [{'인덱스': 70, '코사인 유사도': 0.48696946269120983, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.4673173001814962, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.4669566632467492, '중분류 코드': 'NB06'}],
#  [{'인덱스': 94, '코사인 유사도': 0.39130517286975225, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.3877040351963449, '중분류 코드': 'NC01'},
#   {'인덱스': 55, '코사인 유사도': 0.3844625495143032, '중분류 코드': 'NB06'}],
#  [{'인덱스': 70, '코사인 유사도': 0.7385690612405333, '중분류 코드': 'NB06'},
#   {'인덱스': 56, '코사인 유사도': 0.7300165039223914, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.7295188092131955, '중분류 코드': 'NC01'}],
#  [{'인덱스': 94, '코사인 유사도': 0.4839761915016793, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.4825546678533442, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.4821926553399034, '중분류 코드': 'NB06'}],
#  [{'인덱스': 70, '코사인 유사도': 0.7939340503637916, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.7857503834131225, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.783051243581386, '중분류 코드': 'NB06'}],
#  [{'인덱스': 92, '코사인 유사도': 0.32778577170450784, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.32487560376787905, '중분류 코드': 'NC01'},
#   {'인덱스': 97, '코사인 유사도': 0.3189319786290411, '중분류 코드': 'NC01'}],
#  [{'인덱스': 94, '코사인 유사도': 0.37801688250590904, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.3735588455269966, '중분류 코드': 'NC01'},
#   {'인덱스': 55, '코사인 유사도': 0.3664088560144069, '중분류 코드': 'NB06'}],
#  [{'인덱스': 92, '코사인 유사도': 0.5192616609733709, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.5183668671485685, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.517787081808974, '중분류 코드': 'NB06'}],
#  [{'인덱스': 70, '코사인 유사도': 0.6111543685664654, '중분류 코드': 'NB06'},
#   {'인덱스': 56, '코사인 유사도': 0.6037266236981994, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.6036346957965497, '중분류 코드': 'NC01'}],
#  [{'인덱스': 56, '코사인 유사도': 0.5704651518822738, '중분류 코드': 'NB06'},
#   {'인덱스': 94, '코사인 유사도': 0.568870066100932, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.5688243747007016, '중분류 코드': 'NC01'}],
#  [{'인덱스': 70, '코사인 유사도': 0.8230657689864844, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.8178546413294923, '중분류 코드': 'NC01'},
#   {'인덱스': 8, '코사인 유사도': 0.8153863063210371, '중분류 코드': 'ND10'}],
#  [{'인덱스': 92, '코사인 유사도': 0.562836053512233, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.5612749885258355, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.5600134652942664, '중분류 코드': 'NB06'}],
#  [{'인덱스': 94, '코사인 유사도': 0.33217812650446665, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.3274824406603143, '중분류 코드': 'NC01'},
#   {'인덱스': 55, '코사인 유사도': 0.3267086592818641, '중분류 코드': 'NB06'}],
#  [{'인덱스': 70, '코사인 유사도': 0.7589218824541102, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.7527265532423549, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.7484493045081491, '중분류 코드': 'NB06'}],
#  [{'인덱스': 94, '코사인 유사도': 0.3934744222008531, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.3909505223653193, '중분류 코드': 'NC01'},
#   {'인덱스': 61, '코사인 유사도': 0.3838559097385002, '중분류 코드': 'NB06'}],
#  [{'인덱스': 92, '코사인 유사도': 0.4200927611739587, '중분류 코드': 'NC01'},
#   {'인덱스': 70, '코사인 유사도': 0.41677371529499724, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.41513390466049865, '중분류 코드': 'NC01'}],
#  [{'인덱스': 97, '코사인 유사도': 0.3411798948880837, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.33570255354737766, '중분류 코드': 'NC01'},
#   {'인덱스': 61, '코사인 유사도': 0.32889309420661894, '중분류 코드': 'NB06'}],
#  [{'인덱스': 61, '코사인 유사도': 0.28994356224162837, '중분류 코드': 'NB06'},
#   {'인덱스': 92, '코사인 유사도': 0.2896493147860262, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.28820504622681636, '중분류 코드': 'NC01'}],
#  [{'인덱스': 94, '코사인 유사도': 0.4226385491446586, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.4184661753976402, '중분류 코드': 'NC01'},
#   {'인덱스': 55, '코사인 유사도': 0.4150960636280495, '중분류 코드': 'NB06'}],
#  [{'인덱스': 92, '코사인 유사도': 0.38220034652469176, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.3775287060593935, '중분류 코드': 'NC01'},
#   {'인덱스': 61, '코사인 유사도': 0.3770910537539679, '중분류 코드': 'NB06'}],
#  [{'인덱스': 70, '코사인 유사도': 0.6698770038715771, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.6679213700432555, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.6670959930309234, '중분류 코드': 'NB06'}],
#  [{'인덱스': 70, '코사인 유사도': 0.9424128720519729, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.9408164439363206, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.9402604703736754, '중분류 코드': 'NB06'}],
#  [{'인덱스': 70, '코사인 유사도': 0.9110000978116577, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.9083255708720133, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.90624490009783, '중분류 코드': 'NB06'}],
#  [{'인덱스': 94, '코사인 유사도': 0.4141074983008958, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.4113106514537479, '중분류 코드': 'NC01'},
#   {'인덱스': 55, '코사인 유사도': 0.40453791734415856, '중분류 코드': 'NB06'}],
#  [{'인덱스': 97, '코사인 유사도': 0.27763366631260256, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.275134270681899, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.2721969078252324, '중분류 코드': 'NC01'}],
#  [{'인덱스': 70, '코사인 유사도': 0.7777025195051714, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.7716741156395153, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.7690169096542474, '중분류 코드': 'NB06'}],
#  [{'인덱스': 97, '코사인 유사도': 0.3567315427820093, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.35441411959990615, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.3482006253664619, '중분류 코드': 'NC01'}],
#  [{'인덱스': 92, '코사인 유사도': 0.4667103533714074, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.4666999299566423, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.46239691875666356, '중분류 코드': 'NB06'}],
#  [{'인덱스': 56, '코사인 유사도': 0.6091374006258159, '중분류 코드': 'NB06'},
#   {'인덱스': 92, '코사인 유사도': 0.6063638827942089, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.6058942151256191, '중분류 코드': 'NC01'}],
#  [{'인덱스': 70, '코사인 유사도': 0.42058140471982164, '중분류 코드': 'NB06'},
#   {'인덱스': 92, '코사인 유사도': 0.4029524765657118, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.4016212047584199, '중분류 코드': 'NC01'}],
#  [{'인덱스': 56, '코사인 유사도': 0.5476244311117607, '중분류 코드': 'NB06'},
#   {'인덱스': 94, '코사인 유사도': 0.5426063294250958, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.5421497000444063, '중분류 코드': 'NC01'}],
#  [{'인덱스': 70, '코사인 유사도': 0.811036804799039, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.8035300110789605, '중분류 코드': 'NC01'},
#   {'인덱스': 8, '코사인 유사도': 0.8003343306508607, '중분류 코드': 'ND10'}],
#  [{'인덱스': 70, '코사인 유사도': 0.7900426462915343, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.783565673765052, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.7801724287707146, '중분류 코드': 'NB06'}],
#  [{'인덱스': 92, '코사인 유사도': 0.3941413065548329, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.39352315362015294, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.3917851109964995, '중분류 코드': 'NB06'}],
#  [{'인덱스': 70, '코사인 유사도': 0.8785109612861359, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.8750143264661442, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.8735801934856248, '중분류 코드': 'NB06'}],
#  [{'인덱스': 70, '코사인 유사도': 0.9639872639485416, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.9627853559565257, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.9626526706492861, '중분류 코드': 'NB06'}],
#  [{'인덱스': 92, '코사인 유사도': 0.33965278807128324, '중분류 코드': 'NC01'},
#   {'인덱스': 91, '코사인 유사도': 0.3390654093098855, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.3339494816070369, '중분류 코드': 'NC01'}],
#  [{'인덱스': 94, '코사인 유사도': 0.38285090417738954, '중분류 코드': 'NC01'},
#   {'인덱스': 97, '코사인 유사도': 0.38136995379613564, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.3774815183671359, '중분류 코드': 'NC01'}],
#  [{'인덱스': 70, '코사인 유사도': 0.8999498731702529, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.8967923084781855, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.8956736890305725, '중분류 코드': 'NB06'}],
#  [{'인덱스': 92, '코사인 유사도': 0.34992897509864496, '중분류 코드': 'NC01'},
#   {'인덱스': 97, '코사인 유사도': 0.34401059333720246, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.3421446832823585, '중분류 코드': 'NC01'}],
#  [{'인덱스': 92, '코사인 유사도': 0.44197909681704267, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.4355652535166548, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.4331747322481731, '중분류 코드': 'NB06'}],
#  [{'인덱스': 97, '코사인 유사도': 0.36688043782549523, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.3636236766888518, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.3569589427947846, '중분류 코드': 'NC01'}],
#  [{'인덱스': 56, '코사인 유사도': 0.8233023327537256, '중분류 코드': 'NB06'},
#   {'인덱스': 70, '코사인 유사도': 0.8231249278791292, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.8223653859634137, '중분류 코드': 'NC01'}],
#  [{'인덱스': 56, '코사인 유사도': 0.59267043052845, '중분류 코드': 'NB06'},
#   {'인덱스': 94, '코사인 유사도': 0.5892659936063999, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.5880090100135049, '중분류 코드': 'NC01'}],
#  [{'인덱스': 70, '코사인 유사도': 0.7183259427457435, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.7100717093536203, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.7080815298725368, '중분류 코드': 'NB06'}],
#  [{'인덱스': 94, '코사인 유사도': 0.3717887637042405, '중분류 코드': 'NC01'},
#   {'인덱스': 97, '코사인 유사도': 0.3688493588798671, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.36642182034877957, '중분류 코드': 'NC01'}],
#  [{'인덱스': 70, '코사인 유사도': 0.6621386398218159, '중분류 코드': 'NB06'},
#   {'인덱스': 90, '코사인 유사도': 0.6505982010525079, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.6456223983704027, '중분류 코드': 'NB06'}],
#  [{'인덱스': 97, '코사인 유사도': 0.2943002911858663, '중분류 코드': 'NC01'},
#   {'인덱스': 94, '코사인 유사도': 0.27979154321894, '중분류 코드': 'NC01'},
#   {'인덱스': 61, '코사인 유사도': 0.27438445080266854, '중분류 코드': 'NB06'}],
#  [{'인덱스': 94, '코사인 유사도': 0.39256176238632606, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.3894976533106324, '중분류 코드': 'NC01'},
#   {'인덱스': 61, '코사인 유사도': 0.3826162675296975, '중분류 코드': 'NB06'}],
#  [{'인덱스': 92, '코사인 유사도': 0.32322221671896106, '중분류 코드': 'NC01'},
#   {'인덱스': 61, '코사인 유사도': 0.3222578768749538, '중분류 코드': 'NB06'},
#   {'인덱스': 94, '코사인 유사도': 0.3200867444697743, '중분류 코드': 'NC01'}],
#  [{'인덱스': 94, '코사인 유사도': 0.4859673002300861, '중분류 코드': 'NC01'},
#   {'인덱스': 92, '코사인 유사도': 0.4842037355385654, '중분류 코드': 'NC01'},
#   {'인덱스': 56, '코사인 유사도': 0.4806510204515052, '중분류 코드': 'NB06'}],
#  ...]
